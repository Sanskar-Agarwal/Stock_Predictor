# %%
import yfinance as yf

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-03-11 00:00:00-04:00  5603.649902  5636.299805  5528.410156  5572.069824
# 2025-03-12 00:00:00-04:00  5624.839844  5642.189941  5546.089844  5599.299805
# 2025-03-13 00:00:00-04:00  5594.450195  5597.779785  5504.649902  5521.520020
# 2025-03-14 00:00:00-04:00  5563.850098  5645.270020  5563.850098  5638.939941
# 2025-03-17 00:00:00-04:00  5635.600098  5703.520020  5631.120117  5675.120117
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2025-03-04 00:00:00-05:00', '2025-03-05 00:00:00-05:00',
#                '2025-03-06 00:00:00-05:00', '2025-03-07 00:00:00-05:00',
#                '2025-03-10 00:00:00-04:00', '2025-03-11 00:00:00-04:00',
#                '2025-03-12 00:00:00-04:00', '2025-03-13 00:00:00-04:00',
#                '2025-03-14 00:00:00-04:00', '2025-03-17 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24417, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-03-11 00:00:00-04:00  5603.649902  5636.299805  5528.410156  5572.069824
# 2025-03-12 00:00:00-04:00  5624.839844  5642.189941  5546.089844  5599.299805
# 2025-03-13 00:00:00-04:00  5594.450195  5597.779785  5504.649902  5521.520020
# 2025-03-14 00:00:00-04:00  5563.850098  5645.270020  5563.850098  5638.939941
# 2025-03-17 00:00:00-04:00  5635.600098  5703.520020  5631.120117  5675.120117
#
# ...

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-03-11 00:00:00-04:00  5603.649902  5636.299805  5528.410156  5572.069824
# 2025-03-12 00:00:00-04:00  5624.839844  5642.189941  5546.089844  5599.299805
# 2025-03-13 00:00:00-04:00  5594.450195  5597.779785  5504.649902  5521.520020
# 2025-03-14 00:00:00-04:00  5563.850098  5645.270020  5563.850098  5638.939941
# 2025-03-17 00:00:00-04:00  5635.600098  5703.520020  5631.120117  5675.120117
#
# ...

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2025-03-11 00:00:00-04:00  5603.649902  5636.299805  5528.410156  5572.069824
# 2025-03-12 00:00:00-04:00  5624.839844  5642.189941  5546.089844  5599.299805
# 2025-03-13 00:00:00-04:00  5594.450195  5597.779785  5504.649902  5521.520020
# 2025-03-14 00:00:00-04:00  5563.850098  5645.270020  5563.850098  5638.939941
# 2025-03-17 00:00:00-04:00  5635.600098  5703.520020  5631.120117  5675.120117
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
# RandomForest as they are resistant to overfitting due to randomization
# Run quickly and can pickup non-linear relationships (Eg Open vs Target)

# %%
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd

preds = pd.Series(preds, index=test.index)

# %%
preds
# Out:
# Date
# 2024-10-21 00:00:00-04:00    0
# 2024-10-22 00:00:00-04:00    0
# 2024-10-23 00:00:00-04:00    1
# 2024-10-24 00:00:00-04:00    1
# 2024-10-25 00:00:00-04:00    1
#                             ..
# 2025-03-11 00:00:00-04:00    1
# 2025-03-12 00:00:00-04:00    1
# 2025-03-13 00:00:00-04:00    0
# 2025-03-14 00:00:00-04:00    0
# 2025-03-17 00:00:00-04:00    0
# Length: 100, dtype: int64

# %%
precision_score(test["Target"],preds)
# Out:
# 0.5454545454545454

# %%
#Precision = 0.55, means we were only correct 55% times, not great

combined = pd.concat([test["Target"],preds], axis = 1)
combined.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Orange is our answer, blue are the predictions(Testing only last 100 days)

def prediction(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name = "Predictions")
    combined = pd.concat([test["Target"],preds], axis = 1)
    return combined

# %%
def backtest(data, model, predictors, start=2500,step=250):
    #Every year has 250 trading days, training for 10 years data
    all_predictions = []
    
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predict = prediction(train,test,predictors,model)
        all_predictions.append(predict)
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500,model,predictors)

# %%
predictions
# Out:
#                            Target  Predictions
# Date
# 2003-11-14 00:00:00-05:00       0            0
# 2003-11-17 00:00:00-05:00       0            0
# 2003-11-18 00:00:00-05:00       1            1
# 2003-11-19 00:00:00-05:00       0            1
# 2003-11-20 00:00:00-05:00       1            1
# ...                           ...          ...
# 2025-03-10 00:00:00-04:00       0            1
# 2025-03-11 00:00:00-04:00       1            0
# 2025-03-12 00:00:00-04:00       0            0
# 2025-03-13 00:00:00-04:00       1            0
# 2025-03-14 00:00:00-04:00       1            0
#
# [5366 rows x 2 columns]

# %%
predictions["Predictions"].value_counts()
# Out:
# 0    3371
# 1    1995
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5368421052631579

# %%
#Precision has improved to 71%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# 1    0.545471
# 0    0.454529
# Name: Target, dtype: float64

# %%
#Creating rolling averages

new_predictors = []
horizons = [2,5,60,250,1000]
#2 days, week, 12 weeks, year, 5 years


for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()
    
    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"]/ rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors += [ratio_column, trend_column]

# %%
sp500 = sp500.dropna()
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1997-11-26 00:00:00-05:00   950.820007   956.469971   950.820007   951.640015
# 1997-11-28 00:00:00-05:00   951.640015   959.130005   951.640015   955.400024
# 1997-12-01 00:00:00-05:00   955.400024   974.770020   955.400024   974.770020
# 1997-12-02 00:00:00-05:00   974.780029   976.200012   969.830017   971.679993
# 1997-12-03 00:00:00-05:00   971.679993   980.809998   966.159973   976.770020
# ...                                ...          ...          ...          ...
# 2025-03-10 00:00:00-04:00  5705.370117  5705.370117  5564.020020  5614.560059
# 2025-03-11 00:00:00-04:00  5603.649902  5636.299805  5528.410156  5572.069824
# 2025-03-12 00:00:00-04:00  5624.839844  5642.189941  5546.089844  5599.299805
# 2025-03-13 00:00:00-04:00  5594.450195  5597.779785  5504.649902  5521.520020
# 2025-03-14 00:00:00-04:00  5563.850098  5645.270020  5563.850098  5638.939941
#
# ...

# %%
model = RandomForestClassifier(n_estimators= 200, min_samples_split=50, random_state=1)

# %%
def prediction(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    #Probability that its 0 or 1
    preds = model.predict_proba(test[predictors])[:,1] 
    #Setting higher thershold(confidence) for model to predict going up
    #Will get lesser days where model says stocks go up but with higher confidence
    preds[preds >= .60] = 1
    preds[preds < .60] = 0
    preds = pd.Series(preds, index=test.index, name = "Predictions")
    combined = pd.concat([test["Target"],preds], axis = 1)
    return combined

# %%
predictions = backtest(sp500,model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# 0.0    3791
# 1.0     575
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5704347826086956
